# %%
pip install openai num2words matplotlib plotly scipy scikit-learn pandas tiktoken
# Out:
# Requirement already satisfied: openai in c:\users\yossef\anaconda3\lib\site-packages (1.51.2)
# Requirement already satisfied: num2words in c:\users\yossef\anaconda3\lib\site-packages (0.5.13)
# Requirement already satisfied: matplotlib in c:\users\yossef\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: plotly in c:\users\yossef\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: scipy in c:\users\yossef\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: scikit-learn in c:\users\yossef\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pandas in c:\users\yossef\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: tiktoken in c:\users\yossef\anaconda3\lib\site-packages (0.8.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (0.6.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in c:\users\yossef\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\yossef\anaconda3\lib\site-packages (from openai) (4.11.0)
# Requirement already satisfied: docopt>=0.6.2 in c:\users\yossef\anaconda3\lib\site-packages (from num2words) (0.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\yossef\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\yossef\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\yossef\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\yossef\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\yossef\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\yossef\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\users\yossef\anaconda3\lib\site-packages (from tiktoken) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in c:\users\yossef\anaconda3\lib\site-packages (from tiktoken) (2.32.2)
# Requirement already satisfied: idna>=2.8 in c:\users\yossef\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: certifi in c:\users\yossef\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\yossef\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\yossef\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\yossef\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.23.4 in c:\users\yossef\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: six>=1.5 in c:\users\yossef\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\yossef\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yossef\anaconda3\lib\site-packages (from requests>=2.26.0->tiktoken) (2.2.2)
# Requirement already satisfied: colorama in c:\users\yossef\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %%
import os
import re
import requests
import sys
from num2words import num2words
import os
import pandas as pd
import numpy as np
import tiktoken
from openai import AzureOpenAI
from dotenv import load_dotenv

# %%
df = pd.read_csv('../data/df_concat.csv')

# %%
df_copy = df.copy(deep=True)

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description',
#        'month_added', 'month_name_added', 'year_added', 'type_of_movie'],
#       dtype='object')

# %%
df.head()
# Out:
#   show_id     type                                             title  \
# 0      s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1      s2    Movie                            Ernest Saves Christmas
# 2      s3    Movie                      Ice Age: A Mammoth Christmas
# 3      s4    Movie                        The Queen Family Singalong
# 4      s5  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                            No Data
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...  United States
# 4  John Lennon, Paul McCartney, George Harrison, ...  United States
#
#    date_added  release_year rating  duration                      listed_in  \
# 0  2021-11-26          2016   TV-G    23 min              Animation, Family
# 1  2021-11-26          1988     PG    91 min                         Comedy
# 2  2021-11-26          2011   TV-G    23 min      Animation, Comedy, Family
# 3  2021-11-26          2021  TV-PG    41 min                        Musical
# 4  2021-11-25          2021    NaN  1 Season  Docuseries, Historical, Music
#
#                                          description  month_added  \
# 0   Join Mickey and the gang as they duck the halls!           11
# 1  Santa Claus passes his magic bag to a new St. ...           11
# 2          Sid the Sloth is on Santa's naughty list.           11
# 3               This is real life, not just fantasy!           11
# 4  A three-part documentary from Peter Jackson ca...           11
#
#   month_name_added  year_added type_of_movie
# 0         November        2021     Animation
# 1         November        2021        Comedy
# 2         November        2021     Animation
# 3         November        2021       Musical
# 4         November        2021    Docuseries

# %%
df.replace('No Data', 'no_data', inplace=True)

# %%
df.drop(columns=['show_id','date_added','duration', 'month_added', 'month_name_added', 'year_added', 'type_of_movie'],inplace=True)

# %%
df.head()
# Out:
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso Ramirez Ramos, Dave Wasson
# 1                        John Cherry
# 2                       Karen Disher
# 3                    Hamish Hamilton
# 4                            no_data
#
#                                                 cast        country  \
# 0  Chris Diamantopoulos, Tony Anselmo, Tress MacN...  United States
# 1           Jim Varney, Noelle Parker, Douglas Seale  United States
# 2  Raymond Albert Romano, John Leguizamo, Denis L...  United States
# 3  Darren Criss, Adam Lambert, Derek Hough, Alexa...  United States
# 4  John Lennon, Paul McCartney, George Harrison, ...  United States
#
#    release_year rating                      listed_in  \
# 0          2016   TV-G              Animation, Family
# 1          1988     PG                         Comedy
# 2          2011   TV-G      Animation, Comedy, Family
# 3          2021  TV-PG                        Musical
# 4          2021    NaN  Docuseries, Historical, Music
#
#                                          description
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...

# %%
def create_textual_representation(row):
    txt= f"""Type: {row['type']}
Director: {row['director']}
Cast: {row['cast']}
Release Year: {row['release_year']}
Country: {row['country']}
Genre: {row['listed_in']}

Description: {row['cleaned_description']}"""

    return txt

# %%
def clean_text(text):
    # Remove punctuation
    punctuation = '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
    text = ''.join([char for char in text if char not in punctuation])

    # Convert to lowercase
    text = text.lower()

    # Remove extra whitespace
    text = ' '.join(text.split())

    return text

# %%
def trim_cast(cast_str):
    """Trims the cast string to only the first 3 actors and returns them as a list with spaces replaced by underscores."""
    if isinstance(cast_str, str):
        actors = cast_str.split(',')
        return [actor.strip().replace(' ', '_') for actor in actors[:3]]
    return []

# %%
df['cast'] = df['cast'].apply(lambda x: ', '.join(trim_cast(x)))
df['director'] = df['director'].apply(lambda x: ', '.join(trim_cast(x)))

# %%
df['cleaned_description'] = df['description'].apply(clean_text)

# %%
df['textual_representation']=df.apply(create_textual_representation, axis=1)

# %%
print(df['textual_representation'].values[0])
# Out:
# Type: Movie
# Director: Alonso_Ramirez_Ramos, Dave_Wasson
# Cast: Chris_Diamantopoulos, Tony_Anselmo, Tress_MacNeille
# Release Year: 2016
# Country: United States
# Genre: Animation, Family
#
# Description: join mickey and the gang as they duck the halls

# %%
tokenizer = tiktoken.get_encoding("cl100k_base")
df['n_tokens'] = df["textual_representation"].apply(lambda x: len(tokenizer.encode(x)))

# %%
total_tokens = df['n_tokens'].sum()
print(f"Total number of tokens: {total_tokens}")
print(f"Total cost of tokens: {total_tokens*0.0001/1000} $")
# Out:
# Total number of tokens: 793095
# Total cost of tokens: 0.0793095 $

# %%
df.head()
# Out:
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso_Ramirez_Ramos, Dave_Wasson
# 1                        John_Cherry
# 2                       Karen_Disher
# 3                    Hamish_Hamilton
# 4                            no_data
#
#                                                 cast        country  \
# 0  Chris_Diamantopoulos, Tony_Anselmo, Tress_MacN...  United States
# 1           Jim_Varney, Noelle_Parker, Douglas_Seale  United States
# 2  Raymond_Albert_Romano, John_Leguizamo, Denis_L...  United States
# 3            Darren_Criss, Adam_Lambert, Derek_Hough  United States
# 4       John_Lennon, Paul_McCartney, George_Harrison  United States
#
#    release_year rating                      listed_in  \
# 0          2016   TV-G              Animation, Family
# 1          1988     PG                         Comedy
# 2          2011   TV-G      Animation, Comedy, Family
# 3          2021  TV-PG                        Musical
# 4          2021    NaN  Docuseries, Historical, Music
#
#                                          description  \
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...
#
#                                  cleaned_description  \
# 0    join mickey and the gang as they duck the halls
# 1   santa claus passes his magic bag to a new st nic
# 2            sid the sloth is on santas naughty list
# 3                 this is real life not just fantasy
# 4  a threepart documentary from peter jackson cap...
#
#                               textual_representation  n_tokens
# 0  Type: Movie\nDirector: Alonso_Ramirez_Ramos, D...        70
# 1  Type: Movie\nDirector: John_Cherry\nCast: Jim_...        55
# 2  Type: Movie\nDirector: Karen_Disher\nCast: Ray...        63
# 3  Type: Movie\nDirector: Hamish_Hamilton\nCast: ...        53
# 4  Type: TV Show\nDirector: no_data\nCast: John_L...        70

# %%
load_dotenv()
# Out:
# True

# %%
azure_endpoint = os.getenv("AZURE_ENDPOINT")
api_key = os.getenv("API_KEY")
api_version = os.getenv("API_VERSION")

# %%
client = AzureOpenAI(
    azure_endpoint=azure_endpoint,
    api_key=api_key,
    api_version=api_version
)

# %%
def generate_embeddings(text, model="text-embedding-ada-002"):
    return client.embeddings.create(input = [text], model=model).data[0].embedding

# %%
df['ada_v2'] = df["textual_representation"].apply(lambda x : generate_embeddings (x, model = 'text-embedding-ada-002'))

# %%
df.head()
# Out:
#       type                                             title  \
# 0    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1    Movie                            Ernest Saves Christmas
# 2    Movie                      Ice Age: A Mammoth Christmas
# 3    Movie                        The Queen Family Singalong
# 4  TV Show                             The Beatles: Get Back
#
#                             director  \
# 0  Alonso_Ramirez_Ramos, Dave_Wasson
# 1                        John_Cherry
# 2                       Karen_Disher
# 3                    Hamish_Hamilton
# 4                            no_data
#
#                                                 cast        country  \
# 0  Chris_Diamantopoulos, Tony_Anselmo, Tress_MacN...  United States
# 1           Jim_Varney, Noelle_Parker, Douglas_Seale  United States
# 2  Raymond_Albert_Romano, John_Leguizamo, Denis_L...  United States
# 3            Darren_Criss, Adam_Lambert, Derek_Hough  United States
# 4       John_Lennon, Paul_McCartney, George_Harrison  United States
#
#    release_year rating                      listed_in  \
# 0          2016   TV-G              Animation, Family
# 1          1988     PG                         Comedy
# 2          2011   TV-G      Animation, Comedy, Family
# 3          2021  TV-PG                        Musical
# 4          2021    NaN  Docuseries, Historical, Music
#
#                                          description  \
# 0   Join Mickey and the gang as they duck the halls!
# 1  Santa Claus passes his magic bag to a new St. ...
# 2          Sid the Sloth is on Santa's naughty list.
# 3               This is real life, not just fantasy!
# 4  A three-part documentary from Peter Jackson ca...
#
#                                  cleaned_description  \
# 0    join mickey and the gang as they duck the halls
# 1   santa claus passes his magic bag to a new st nic
# 2            sid the sloth is on santas naughty list
# 3                 this is real life not just fantasy
# 4  a threepart documentary from peter jackson cap...
#
#                               textual_representation  n_tokens  \
# 0  Type: Movie\nDirector: Alonso_Ramirez_Ramos, D...        70
# 1  Type: Movie\nDirector: John_Cherry\nCast: Jim_...        55
# 2  Type: Movie\nDirector: Karen_Disher\nCast: Ray...        63
# 3  Type: Movie\nDirector: Hamish_Hamilton\nCast: ...        53
# 4  Type: TV Show\nDirector: no_data\nCast: John_L...        70
#
#                                               ada_v2
# 0  [-0.004417451564222574, -0.02741820551455021, ...
# 1  [0.0017536545637995005, -0.0326634906232357, -...
# 2  [-0.00391661049798131, -0.015575433149933815, ...
# 3  [-0.0018677887273952365, -0.02954970672726631,...
# 4  [-0.003931119572371244, -0.02340295910835266, ...

# %%
df.to_csv('df_with_embeddings.csv', index=False)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Extract the embeddings as a NumPy array
embeddings_matrix = np.stack(df['ada_v2'].values)

# Calculate the cosine similarity matrix
cosine_sim_matrix = cosine_similarity(embeddings_matrix)

# You now have a cosine similarity matrix where cosine_sim_matrix[i][j] represents the
# cosine similarity between the embedding of item i and item j.

print(cosine_sim_matrix)
# Out:
# [[1.         0.80712338 0.83416796 ... 0.82279704 0.84654992 0.81210712]
#  [0.80712338 1.         0.84250461 ... 0.80016005 0.83202288 0.78629445]
#  [0.83416796 0.84250461 1.         ... 0.80564048 0.83435901 0.79409077]
#  ...
#  [0.82279704 0.80016005 0.80564048 ... 1.         0.83621743 0.82755757]
#  [0.84654992 0.83202288 0.83435901 ... 0.83621743 1.         0.81765859]
#  [0.81210712 0.78629445 0.79409077 ... 0.82755757 0.81765859 1.        ]]

# %%
cosine_sim_df = pd.DataFrame(cosine_sim_matrix, index=df['title'], columns=df['title'])

# %%
cosine_sim_df.head()
# Out:
# title                                             Duck the Halls: A Mickey Mouse Christmas Special  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                                          1.000000
# Ernest Saves Christmas                                                                    0.807123
# Ice Age: A Mammoth Christmas                                                              0.834168
# The Queen Family Singalong                                                                0.810547
# The Beatles: Get Back                                                                     0.784283
#
# title                                             Ernest Saves Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.807123
# Ernest Saves Christmas                                          1.000000
# Ice Age: A Mammoth Christmas                                    0.842505
# The Queen Family Singalong                                      0.780857
# The Beatles: Get Back                                           0.769345
#
# title                                             Ice Age: A Mammoth Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                      0.834168
# Ernest Saves Christmas                                                0.842505
# Ice Age: A Mammoth Christmas                                          1.000000
# The Queen Family Singalong                                            0.786400
# The Beatles: Get Back                                                 0.755399
#
# title                                             The Queen Family Singalong  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                    0.810547
# Ernest Saves Christmas                                              0.780857
# Ice Age: A Mammoth Christmas                                        0.786400
# The Queen Family Singalong                                          1.000000
# The Beatles: Get Back                                               0.807295
#
# title                                             The Beatles: Get Back  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special               0.784283
# Ernest Saves Christmas                                         0.769345
# Ice Age: A Mammoth Christmas                                   0.755399
# The Queen Family Singalong                                     0.807295
# The Beatles: Get Back                                          1.000000
#
# title                                             Becoming Cousteau   Hawkeye  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special           0.800482  0.813161
# Ernest Saves Christmas                                     0.761354  0.790955
# Ice Age: A Mammoth Christmas                               0.772180  0.774309
# The Queen Family Singalong                                 0.785453  0.793144
# The Beatles: Get Back                                      0.783441  0.804394
#
# title                                             Port Protection Alaska  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.773711
# Ernest Saves Christmas                                          0.756960
# Ice Age: A Mammoth Christmas                                    0.746722
# The Queen Family Singalong                                      0.769655
# The Beatles: Get Back                                           0.793175
#
# title                                             Secrets of the Zoo: Tampa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                   0.792548
# Ernest Saves Christmas                                             0.755780
# Ice Age: A Mammoth Christmas                                       0.786799
# The Queen Family Singalong                                         0.797083
# The Beatles: Get Back                                              0.803530
#
# title                                             A Muppets Christmas: Letters To Santa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                               0.850717
# Ernest Saves Christmas                                                         0.836986
# Ice Age: A Mammoth Christmas                                                   0.840568
# The Queen Family Singalong                                                     0.817454
# The Beatles: Get Back                                                          0.805328
#
# title                                             ...  Zak Storm  Zed Plus  \
# title                                             ...
# Duck the Halls: A Mickey Mouse Christmas Special  ...   0.811230  0.797384
# Ernest Saves Christmas                            ...   0.794159  0.774040
# Ice Age: A Mammoth Christmas                      ...   0.789827  0.790898
# The Queen Family Singalong                        ...   0.788258  0.802543
# The Beatles: Get Back                             ...   0.807186  0.765266
#
# title                                                Zenda  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.794955
# Ernest Saves Christmas                            0.790786
# Ice Age: A Mammoth Christmas                      0.799528
# The Queen Family Singalong                        0.798481
# The Beatles: Get Back                             0.794759
#
# title                                             Zindagi Gulzar Hai  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special            0.762370
# Ernest Saves Christmas                                      0.767041
# Ice Age: A Mammoth Christmas                                0.762349
# The Queen Family Singalong                                  0.782910
# The Beatles: Get Back                                       0.775549
#
# title                                              Zinzana    Zodiac  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.788737  0.802589
# Ernest Saves Christmas                            0.771957  0.783414
# Ice Age: A Mammoth Christmas                      0.780361  0.801237
# The Queen Family Singalong                        0.795280  0.789028
# The Beatles: Get Back                             0.765019  0.788894
#
# title                                             Zombie Dumb  Zombieland  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special     0.810550    0.822797
# Ernest Saves Christmas                               0.786400    0.800160
# Ice Age: A Mammoth Christmas                         0.786025    0.805640
# The Queen Family Singalong                           0.784736    0.800242
# The Beatles: Get Back                                0.786737    0.775822
#
# title                                                 Zoom    Zubaan
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.846550  0.812107
# Ernest Saves Christmas                            0.832023  0.786294
# Ice Age: A Mammoth Christmas                      0.834359  0.794091
# The Queen Family Singalong                        0.812716  0.823941
# The Beatles: Get Back                             0.786633  0.798765
#
# [5 rows x 10218 columns]

# %%
def get_recommendations(title, cosine_sim_df, top_n=10):
  """
  Recommends similar movies based on cosine similarity.

  Args:
      title: The title of the movie for which to find recommendations.
      cosine_sim_df: A DataFrame containing the cosine similarity matrix.
      top_n: The number of top similar movies to return.

  Returns:
      A list of recommended movie titles.
  """
  try:
    # Get the row corresponding to the given title
    similarity_scores = cosine_sim_df.loc[title]

    # Sort the similarity scores in descending order
    similarity_scores = similarity_scores.sort_values(ascending=False)

    # Get the top N similar movies (excluding the movie itself)
    top_similar_movies = similarity_scores[1:top_n + 1].index.tolist()

    return top_similar_movies
  except KeyError:
    print(f"Movie '{title}' not found in the dataset.")
    return []

# %%
movie_title = "The Matrix Reloaded"
recommended_movies = get_recommendations(movie_title, cosine_sim_df, top_n=5)

print(f"Top 5 recommendations for '{movie_title}':")
for movie in recommended_movies:
  print(movie)
# Out:
# Top 5 recommendations for 'The Matrix Reloaded':
# The Matrix Revolutions
# The Matrix
# Jupiter Ascending
# Æon Flux
# Singularity

# %%
import pickle

with open('cosine_sim_df.pickle', 'wb') as f:
    pickle.dump(cosine_sim_df, f)

# %%
import pickle

# Load the DataFrame from the pickle file
with open('../data/cosine_sim_df_32.pickle', 'rb') as f:
    cosine_sim_df = pickle.load(f)

print(cosine_sim_df)
# Out:
# title                                             Duck the Halls: A Mickey Mouse Christmas Special  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                                          1.000000
# Ernest Saves Christmas                                                                    0.807123
# Ice Age: A Mammoth Christmas                                                              0.834168
# The Queen Family Singalong                                                                0.810547
# The Beatles: Get Back                                                                     0.784283
# ...                                                                                            ...
# Zodiac                                                                                    0.802589
# Zombie Dumb                                                                               0.810550
# Zombieland                                                                                0.822797
# Zoom                                                                                      0.846550
# Zubaan                                                                                    0.812107
#
# title                                             Ernest Saves Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.807123
# Ernest Saves Christmas                                          1.000000
# Ice Age: A Mammoth Christmas                                    0.842505
# The Queen Family Singalong                                      0.780857
# The Beatles: Get Back                                           0.769345
# ...                                                                  ...
# Zodiac                                                          0.783414
# Zombie Dumb                                                     0.786400
# Zombieland                                                      0.800160
# Zoom                                                            0.832023
# Zubaan                                                          0.786294
#
# title                                             Ice Age: A Mammoth Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                      0.834168
# Ernest Saves Christmas                                                0.842505
# Ice Age: A Mammoth Christmas                                          1.000000
# The Queen Family Singalong                                            0.786400
# The Beatles: Get Back                                                 0.755399
# ...                                                                        ...
# Zodiac                                                                0.801237
# Zombie Dumb                                                           0.786025
# Zombieland                                                            0.805640
# Zoom                                                                  0.834359
# Zubaan                                                                0.794091
#
# title                                             The Queen Family Singalong  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                    0.810547
# Ernest Saves Christmas                                              0.780857
# Ice Age: A Mammoth Christmas                                        0.786400
# The Queen Family Singalong                                          1.000000
# The Beatles: Get Back                                               0.807295
# ...                                                                      ...
# Zodiac                                                              0.789028
# Zombie Dumb                                                         0.784736
# Zombieland                                                          0.800242
# Zoom                                                                0.812716
# Zubaan                                                              0.823941
#
# title                                             The Beatles: Get Back  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special               0.784283
# Ernest Saves Christmas                                         0.769345
# Ice Age: A Mammoth Christmas                                   0.755399
# The Queen Family Singalong                                     0.807295
# The Beatles: Get Back                                          1.000000
# ...                                                                 ...
# Zodiac                                                         0.788894
# Zombie Dumb                                                    0.786737
# Zombieland                                                     0.775822
# Zoom                                                           0.786633
# Zubaan                                                         0.798765
#
# title                                             Becoming Cousteau   Hawkeye  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special           0.800482  0.813161
# Ernest Saves Christmas                                     0.761354  0.790955
# Ice Age: A Mammoth Christmas                               0.772180  0.774309
# The Queen Family Singalong                                 0.785453  0.793144
# The Beatles: Get Back                                      0.783441  0.804394
# ...                                                             ...       ...
# Zodiac                                                     0.803780  0.808546
# Zombie Dumb                                                0.765456  0.835975
# Zombieland                                                 0.789593  0.822566
# Zoom                                                       0.800147  0.835730
# Zubaan                                                     0.785603  0.807252
#
# title                                             Port Protection Alaska  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.773711
# Ernest Saves Christmas                                          0.756960
# Ice Age: A Mammoth Christmas                                    0.746722
# The Queen Family Singalong                                      0.769655
# The Beatles: Get Back                                           0.793175
# ...                                                                  ...
# Zodiac                                                          0.789826
# Zombie Dumb                                                     0.803638
# Zombieland                                                      0.796675
# Zoom                                                            0.785439
# Zubaan                                                          0.770001
#
# title                                             Secrets of the Zoo: Tampa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                   0.792548
# Ernest Saves Christmas                                             0.755780
# Ice Age: A Mammoth Christmas                                       0.786799
# The Queen Family Singalong                                         0.797083
# The Beatles: Get Back                                              0.803530
# ...                                                                     ...
# Zodiac                                                             0.805857
# Zombie Dumb                                                        0.816970
# Zombieland                                                         0.780594
# Zoom                                                               0.804163
# Zubaan                                                             0.782566
#
# title                                             A Muppets Christmas: Letters To Santa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                               0.850717
# Ernest Saves Christmas                                                         0.836986
# Ice Age: A Mammoth Christmas                                                   0.840568
# The Queen Family Singalong                                                     0.817454
# The Beatles: Get Back                                                          0.805328
# ...                                                                                 ...
# Zodiac                                                                         0.791227
# Zombie Dumb                                                                    0.810710
# Zombieland                                                                     0.812280
# Zoom                                                                           0.830694
# Zubaan                                                                         0.813802
#
# title                                             ...  Zak Storm  Zed Plus  \
# title                                             ...
# Duck the Halls: A Mickey Mouse Christmas Special  ...   0.811230  0.797384
# Ernest Saves Christmas                            ...   0.794159  0.774040
# Ice Age: A Mammoth Christmas                      ...   0.789827  0.790898
# The Queen Family Singalong                        ...   0.788258  0.802543
# The Beatles: Get Back                             ...   0.807186  0.765266
# ...                                               ...        ...       ...
# Zodiac                                            ...   0.824203  0.813008
# Zombie Dumb                                       ...   0.860904  0.778934
# Zombieland                                        ...   0.805285  0.809110
# Zoom                                              ...   0.835147  0.826910
# Zubaan                                            ...   0.815997  0.865979
#
# title                                                Zenda  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.794955
# Ernest Saves Christmas                            0.790786
# Ice Age: A Mammoth Christmas                      0.799528
# The Queen Family Singalong                        0.798481
# The Beatles: Get Back                             0.794759
# ...                                                    ...
# Zodiac                                            0.821407
# Zombie Dumb                                       0.776475
# Zombieland                                        0.809492
# Zoom                                              0.825234
# Zubaan                                            0.867828
#
# title                                             Zindagi Gulzar Hai  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special            0.762370
# Ernest Saves Christmas                                      0.767041
# Ice Age: A Mammoth Christmas                                0.762349
# The Queen Family Singalong                                  0.782910
# The Beatles: Get Back                                       0.775549
# ...                                                              ...
# Zodiac                                                      0.791793
# Zombie Dumb                                                 0.825795
# Zombieland                                                  0.802610
# Zoom                                                        0.801642
# Zubaan                                                      0.849059
#
# title                                              Zinzana    Zodiac  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.788737  0.802589
# Ernest Saves Christmas                            0.771957  0.783414
# Ice Age: A Mammoth Christmas                      0.780361  0.801237
# The Queen Family Singalong                        0.795280  0.789028
# The Beatles: Get Back                             0.765019  0.788894
# ...                                                    ...       ...
# Zodiac                                            0.817326  1.000000
# Zombie Dumb                                       0.790608  0.818109
# Zombieland                                        0.822427  0.844506
# Zoom                                              0.815082  0.832543
# Zubaan                                            0.831059  0.814088
#
# title                                             Zombie Dumb  Zombieland  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special     0.810550    0.822797
# Ernest Saves Christmas                               0.786400    0.800160
# Ice Age: A Mammoth Christmas                         0.786025    0.805640
# The Queen Family Singalong                           0.784736    0.800242
# The Beatles: Get Back                                0.786737    0.775822
# ...                                                       ...         ...
# Zodiac                                               0.818109    0.844506
# Zombie Dumb                                          1.000000    0.845814
# Zombieland                                           0.845814    1.000000
# Zoom                                                 0.825196    0.836217
# Zubaan                                               0.817400    0.827558
#
# title                                                 Zoom    Zubaan
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.846550  0.812107
# Ernest Saves Christmas                            0.832023  0.786294
# Ice Age: A Mammoth Christmas                      0.834359  0.794091
# The Queen Family Singalong                        0.812716  0.823941
# The Beatles: Get Back                             0.786633  0.798765
# ...                                                    ...       ...
# Zodiac                                            0.832543  0.814088
# Zombie Dumb                                       0.825196  0.817400
# Zombieland                                        0.836217  0.827558
# Zoom                                              1.000000  0.817659
# Zubaan                                            0.817659  1.000000
#
# [10218 rows x 10218 columns]

# %%
cosine_sim_df
# Out:
# title                                             Duck the Halls: A Mickey Mouse Christmas Special  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                                          1.000000
# Ernest Saves Christmas                                                                    0.807123
# Ice Age: A Mammoth Christmas                                                              0.834168
# The Queen Family Singalong                                                                0.810547
# The Beatles: Get Back                                                                     0.784283
# ...                                                                                            ...
# Zodiac                                                                                    0.802589
# Zombie Dumb                                                                               0.810550
# Zombieland                                                                                0.822797
# Zoom                                                                                      0.846550
# Zubaan                                                                                    0.812107
#
# title                                             Ernest Saves Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.807123
# Ernest Saves Christmas                                          1.000000
# Ice Age: A Mammoth Christmas                                    0.842505
# The Queen Family Singalong                                      0.780857
# The Beatles: Get Back                                           0.769345
# ...                                                                  ...
# Zodiac                                                          0.783414
# Zombie Dumb                                                     0.786400
# Zombieland                                                      0.800160
# Zoom                                                            0.832023
# Zubaan                                                          0.786294
#
# title                                             Ice Age: A Mammoth Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                      0.834168
# Ernest Saves Christmas                                                0.842505
# Ice Age: A Mammoth Christmas                                          1.000000
# The Queen Family Singalong                                            0.786400
# The Beatles: Get Back                                                 0.755399
# ...                                                                        ...
# Zodiac                                                                0.801237
# Zombie Dumb                                                           0.786025
# Zombieland                                                            0.805640
# Zoom                                                                  0.834359
# Zubaan                                                                0.794091
#
# title                                             The Queen Family Singalong  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                    0.810547
# Ernest Saves Christmas                                              0.780857
# Ice Age: A Mammoth Christmas                                        0.786400
# The Queen Family Singalong                                          1.000000
# The Beatles: Get Back                                               0.807295
# ...                                                                      ...
# Zodiac                                                              0.789028
# Zombie Dumb                                                         0.784736
# Zombieland                                                          0.800242
# Zoom                                                                0.812716
# Zubaan                                                              0.823941
#
# title                                             The Beatles: Get Back  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special               0.784283
# Ernest Saves Christmas                                         0.769345
# Ice Age: A Mammoth Christmas                                   0.755399
# The Queen Family Singalong                                     0.807295
# The Beatles: Get Back                                          1.000000
# ...                                                                 ...
# Zodiac                                                         0.788894
# Zombie Dumb                                                    0.786737
# Zombieland                                                     0.775822
# Zoom                                                           0.786633
# Zubaan                                                         0.798765
#
# title                                             Becoming Cousteau   Hawkeye  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special           0.800482  0.813161
# Ernest Saves Christmas                                     0.761354  0.790955
# Ice Age: A Mammoth Christmas                               0.772180  0.774309
# The Queen Family Singalong                                 0.785453  0.793144
# The Beatles: Get Back                                      0.783441  0.804394
# ...                                                             ...       ...
# Zodiac                                                     0.803780  0.808546
# Zombie Dumb                                                0.765456  0.835975
# Zombieland                                                 0.789593  0.822566
# Zoom                                                       0.800147  0.835730
# Zubaan                                                     0.785603  0.807252
#
# title                                             Port Protection Alaska  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                0.773711
# Ernest Saves Christmas                                          0.756960
# Ice Age: A Mammoth Christmas                                    0.746722
# The Queen Family Singalong                                      0.769655
# The Beatles: Get Back                                           0.793175
# ...                                                                  ...
# Zodiac                                                          0.789826
# Zombie Dumb                                                     0.803638
# Zombieland                                                      0.796675
# Zoom                                                            0.785439
# Zubaan                                                          0.770001
#
# title                                             Secrets of the Zoo: Tampa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                   0.792548
# Ernest Saves Christmas                                             0.755780
# Ice Age: A Mammoth Christmas                                       0.786799
# The Queen Family Singalong                                         0.797083
# The Beatles: Get Back                                              0.803530
# ...                                                                     ...
# Zodiac                                                             0.805857
# Zombie Dumb                                                        0.816970
# Zombieland                                                         0.780594
# Zoom                                                               0.804163
# Zubaan                                                             0.782566
#
# title                                             A Muppets Christmas: Letters To Santa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                               0.850717
# Ernest Saves Christmas                                                         0.836986
# Ice Age: A Mammoth Christmas                                                   0.840568
# The Queen Family Singalong                                                     0.817454
# The Beatles: Get Back                                                          0.805328
# ...                                                                                 ...
# Zodiac                                                                         0.791227
# Zombie Dumb                                                                    0.810710
# Zombieland                                                                     0.812280
# Zoom                                                                           0.830694
# Zubaan                                                                         0.813802
#
# title                                             ...  Zak Storm  Zed Plus  \
# title                                             ...
# Duck the Halls: A Mickey Mouse Christmas Special  ...   0.811230  0.797384
# Ernest Saves Christmas                            ...   0.794159  0.774040
# Ice Age: A Mammoth Christmas                      ...   0.789827  0.790898
# The Queen Family Singalong                        ...   0.788258  0.802543
# The Beatles: Get Back                             ...   0.807186  0.765266
# ...                                               ...        ...       ...
# Zodiac                                            ...   0.824203  0.813008
# Zombie Dumb                                       ...   0.860904  0.778934
# Zombieland                                        ...   0.805285  0.809110
# Zoom                                              ...   0.835147  0.826910
# Zubaan                                            ...   0.815997  0.865979
#
# title                                                Zenda  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.794955
# Ernest Saves Christmas                            0.790786
# Ice Age: A Mammoth Christmas                      0.799528
# The Queen Family Singalong                        0.798481
# The Beatles: Get Back                             0.794759
# ...                                                    ...
# Zodiac                                            0.821407
# Zombie Dumb                                       0.776475
# Zombieland                                        0.809492
# Zoom                                              0.825234
# Zubaan                                            0.867828
#
# title                                             Zindagi Gulzar Hai  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special            0.762370
# Ernest Saves Christmas                                      0.767041
# Ice Age: A Mammoth Christmas                                0.762349
# The Queen Family Singalong                                  0.782910
# The Beatles: Get Back                                       0.775549
# ...                                                              ...
# Zodiac                                                      0.791793
# Zombie Dumb                                                 0.825795
# Zombieland                                                  0.802610
# Zoom                                                        0.801642
# Zubaan                                                      0.849059
#
# title                                              Zinzana    Zodiac  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.788737  0.802589
# Ernest Saves Christmas                            0.771957  0.783414
# Ice Age: A Mammoth Christmas                      0.780361  0.801237
# The Queen Family Singalong                        0.795280  0.789028
# The Beatles: Get Back                             0.765019  0.788894
# ...                                                    ...       ...
# Zodiac                                            0.817326  1.000000
# Zombie Dumb                                       0.790608  0.818109
# Zombieland                                        0.822427  0.844506
# Zoom                                              0.815082  0.832543
# Zubaan                                            0.831059  0.814088
#
# title                                             Zombie Dumb  Zombieland  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special     0.810550    0.822797
# Ernest Saves Christmas                               0.786400    0.800160
# Ice Age: A Mammoth Christmas                         0.786025    0.805640
# The Queen Family Singalong                           0.784736    0.800242
# The Beatles: Get Back                                0.786737    0.775822
# ...                                                       ...         ...
# Zodiac                                               0.818109    0.844506
# Zombie Dumb                                          1.000000    0.845814
# Zombieland                                           0.845814    1.000000
# Zoom                                                 0.825196    0.836217
# Zubaan                                               0.817400    0.827558
#
# title                                                 Zoom    Zubaan
# title
# Duck the Halls: A Mickey Mouse Christmas Special  0.846550  0.812107
# Ernest Saves Christmas                            0.832023  0.786294
# Ice Age: A Mammoth Christmas                      0.834359  0.794091
# The Queen Family Singalong                        0.812716  0.823941
# The Beatles: Get Back                             0.786633  0.798765
# ...                                                    ...       ...
# Zodiac                                            0.832543  0.814088
# Zombie Dumb                                       0.825196  0.817400
# Zombieland                                        0.836217  0.827558
# Zoom                                              1.000000  0.817659
# Zubaan                                            0.817659  1.000000
#
# [10218 rows x 10218 columns]

# %%
# Calculate the memory usage in bytes
memory_usage_bytes = cosine_sim_df.memory_usage(deep=True).sum()

# Convert bytes to megabytes
memory_usage_mb = memory_usage_bytes / (1024 ** 2)

print(f"Memory usage of the DataFrame: {memory_usage_mb:.2f} MB")
# Out:
# Memory usage of the DataFrame: 398.94 MB

# %%
cosine_sim_df1 = cosine_sim_df.astype(np.float32)

# Calculate the new memory usage in bytes
new_memory_usage_bytes = cosine_sim_df1.memory_usage(deep=True).sum()

# Convert bytes to megabytes
new_memory_usage_mb = new_memory_usage_bytes / (1024 ** 2)

print(f"New memory usage of the DataFrame: {new_memory_usage_mb:.2f} MB")
# Out:
# New memory usage of the DataFrame: 399.20 MB

# %%
# Check if the DataFrames are identical
are_identical = cosine_sim_df.equals(cosine_sim_df1)
print(f"Are the DataFrames identical? {are_identical}")

# Find the differences
differences = cosine_sim_df - cosine_sim_df1

# Check for any non-zero differences
non_zero_differences = differences[differences != 0].dropna(how='all')
print("Non-zero differences between the DataFrames:")
print(non_zero_differences)
# Out:
# Are the DataFrames identical? False
# Non-zero differences between the DataFrames:
# title                                             Duck the Halls: A Mickey Mouse Christmas Special  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                                      2.220446e-16
# Ernest Saves Christmas                                                                1.652363e-08
# Ice Age: A Mammoth Christmas                                                          6.227653e-09
# The Queen Family Singalong                                                           -1.152215e-08
# The Beatles: Get Back                                                                -7.499368e-09
# ...                                                                                            ...
# Zodiac                                                                               -1.970447e-09
# Zombie Dumb                                                                           2.623732e-08
# Zombieland                                                                           -1.812137e-08
# Zoom                                                                                 -1.280369e-08
# Zubaan                                                                               -2.308524e-08
#
# title                                             Ernest Saves Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special            1.652363e-08
# Ernest Saves Christmas                                     -9.992007e-16
# Ice Age: A Mammoth Christmas                               -1.509850e-08
# The Queen Family Singalong                                  2.091807e-08
# The Beatles: Get Back                                      -2.568563e-08
# ...                                                                  ...
# Zodiac                                                      1.902026e-08
# Zombie Dumb                                                 2.021405e-08
# Zombieland                                                 -2.595800e-09
# Zoom                                                       -2.971631e-08
# Zubaan                                                     -1.469071e-08
#
# title                                             Ice Age: A Mammoth Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                  6.227653e-09
# Ernest Saves Christmas                                           -1.509850e-08
# Ice Age: A Mammoth Christmas                                               NaN
# The Queen Family Singalong                                       -2.289185e-09
# The Beatles: Get Back                                            -1.663467e-08
# ...                                                                        ...
# Zodiac                                                            2.074595e-10
# Zombie Dumb                                                       5.324672e-09
# Zombieland                                                        2.577316e-08
# Zoom                                                              1.895904e-08
# Zubaan                                                            1.771696e-08
#
# title                                             The Queen Family Singalong  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special               -1.152215e-08
# Ernest Saves Christmas                                          2.091807e-08
# Ice Age: A Mammoth Christmas                                   -2.289185e-09
# The Queen Family Singalong                                               NaN
# The Beatles: Get Back                                          -9.114829e-09
# ...                                                                      ...
# Zodiac                                                         -1.818058e-08
# Zombie Dumb                                                    -2.169410e-08
# Zombieland                                                      1.096099e-08
# Zoom                                                            2.059419e-08
# Zubaan                                                         -1.646815e-08
#
# title                                             The Beatles: Get Back  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special          -7.499368e-09
# Ernest Saves Christmas                                    -2.568563e-08
# Ice Age: A Mammoth Christmas                              -1.663467e-08
# The Queen Family Singalong                                -9.114829e-09
# The Beatles: Get Back                                               NaN
# ...                                                                 ...
# Zodiac                                                     5.775182e-09
# Zombie Dumb                                                1.704469e-08
# Zombieland                                                 2.392026e-08
# Zoom                                                       1.344582e-08
# Zubaan                                                     4.654362e-09
#
# title                                             Becoming Cousteau  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special      -2.198570e-08
# Ernest Saves Christmas                                -2.179413e-08
# Ice Age: A Mammoth Christmas                           2.453709e-08
# The Queen Family Singalong                             2.403032e-08
# The Beatles: Get Back                                 -2.756923e-08
# ...                                                             ...
# Zodiac                                                -9.722748e-09
# Zombie Dumb                                           -2.557839e-08
# Zombieland                                             8.181233e-09
# Zoom                                                  -9.458134e-09
# Zubaan                                                -9.267269e-09
#
# title                                                  Hawkeye  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  2.290304e-08
# Ernest Saves Christmas                           -3.778168e-10
# Ice Age: A Mammoth Christmas                     -2.796784e-08
# The Queen Family Singalong                       -2.358791e-08
# The Beatles: Get Back                             2.778071e-08
# ...                                                        ...
# Zodiac                                            2.252651e-08
# Zombie Dumb                                       1.699923e-08
# Zombieland                                       -8.208098e-09
# Zoom                                              3.679112e-09
# Zubaan                                            1.453180e-08
#
# title                                             Port Protection Alaska  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special           -2.594804e-08
# Ernest Saves Christmas                                      2.949284e-08
# Ice Age: A Mammoth Christmas                               -2.965700e-08
# The Queen Family Singalong                                  5.764674e-09
# The Beatles: Get Back                                       8.805314e-09
# ...                                                                  ...
# Zodiac                                                     -1.675894e-08
# Zombie Dumb                                                -4.026796e-09
# Zombieland                                                  1.292308e-08
# Zoom                                                       -2.328941e-08
# Zubaan                                                     -3.479935e-10
#
# title                                             Secrets of the Zoo: Tampa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special              -2.928809e-09
# Ernest Saves Christmas                                        -1.669076e-08
# Ice Age: A Mammoth Christmas                                   2.499199e-08
# The Queen Family Singalong                                    -9.980401e-09
# The Beatles: Get Back                                         -6.242502e-09
# ...                                                                     ...
# Zodiac                                                        -1.032797e-08
# Zombie Dumb                                                    1.408377e-09
# Zombieland                                                     2.917705e-08
# Zoom                                                           4.379522e-09
# Zubaan                                                        -2.164909e-08
#
# title                                             A Muppets Christmas: Letters To Santa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                           5.973625e-09
# Ernest Saves Christmas                                                     2.969237e-08
# Ice Age: A Mammoth Christmas                                              -2.211633e-08
# The Queen Family Singalong                                                -1.159898e-09
# The Beatles: Get Back                                                     -1.543187e-08
# ...                                                                                 ...
# Zodiac                                                                    -2.702201e-08
# Zombie Dumb                                                                1.123894e-08
# Zombieland                                                                -4.808069e-10
# Zoom                                                                      -1.476667e-08
# Zubaan                                                                     1.136509e-08
#
# title                                             ...     Zak Storm  \
# title                                             ...
# Duck the Halls: A Mickey Mouse Christmas Special  ...  1.993738e-08
# Ernest Saves Christmas                            ...  2.386660e-08
# Ice Age: A Mammoth Christmas                      ... -1.938156e-08
# The Queen Family Singalong                        ... -1.505063e-09
# The Beatles: Get Back                             ... -1.010771e-08
# ...                                               ...           ...
# Zodiac                                            ...  1.823680e-08
# Zombie Dumb                                       ... -1.044032e-08
# Zombieland                                        ...  1.217867e-08
# Zoom                                              ... -2.793000e-08
# Zubaan                                            ...  3.664237e-09
#
# title                                                 Zed Plus         Zenda  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special -2.447984e-08 -3.132743e-09
# Ernest Saves Christmas                           -5.466155e-09 -1.720849e-09
# Ice Age: A Mammoth Christmas                     -1.425107e-09  5.247664e-09
# The Queen Family Singalong                        1.440501e-08 -2.060415e-08
# The Beatles: Get Back                            -2.541977e-08  1.969841e-08
# ...                                                        ...           ...
# Zodiac                                           -2.838809e-08  1.833409e-08
# Zombie Dumb                                      -2.262831e-08 -2.186094e-08
# Zombieland                                        1.394895e-08  1.010210e-08
# Zoom                                              2.799868e-08  2.130835e-08
# Zubaan                                            2.573841e-08  1.242346e-08
#
# title                                             Zindagi Gulzar Hai  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special        2.512429e-08
# Ernest Saves Christmas                                 -6.858093e-09
# Ice Age: A Mammoth Christmas                           -1.900347e-08
# The Queen Family Singalong                             -3.645117e-09
# The Beatles: Get Back                                  -5.275413e-09
# ...                                                              ...
# Zodiac                                                  3.689068e-09
# Zombie Dumb                                             2.132165e-08
# Zombieland                                              5.061735e-09
# Zoom                                                    2.548399e-08
# Zubaan                                                  3.713874e-09
#
# title                                                  Zinzana        Zodiac  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special -1.337330e-09 -1.970447e-09
# Ernest Saves Christmas                           -2.245289e-08  1.902026e-08
# Ice Age: A Mammoth Christmas                     -2.055456e-08  2.074595e-10
# The Queen Family Singalong                       -1.598998e-08 -1.818058e-08
# The Beatles: Get Back                            -2.562514e-08  5.775182e-09
# ...                                                        ...           ...
# Zodiac                                            3.776930e-09  1.110223e-15
# Zombie Dumb                                       3.814231e-09  2.268134e-08
# Zombieland                                        1.838143e-08 -6.339777e-09
# Zoom                                             -5.472462e-09 -5.359235e-09
# Zubaan                                            6.067541e-09  2.904548e-08
#
# title                                              Zombie Dumb    Zombieland  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  2.623732e-08 -1.812137e-08
# Ernest Saves Christmas                            2.021405e-08 -2.595800e-09
# Ice Age: A Mammoth Christmas                      5.324672e-09  2.577316e-08
# The Queen Family Singalong                       -2.169410e-08  1.096099e-08
# The Beatles: Get Back                             1.704469e-08  2.392026e-08
# ...                                                        ...           ...
# Zodiac                                            2.268134e-08 -6.339777e-09
# Zombie Dumb                                       8.881784e-16  2.931105e-08
# Zombieland                                        2.931105e-08 -4.440892e-16
# Zoom                                              1.069424e-08 -2.830602e-08
# Zubaan                                           -6.595572e-09  4.135392e-09
#
# title                                                     Zoom        Zubaan
# title
# Duck the Halls: A Mickey Mouse Christmas Special -1.280369e-08 -2.308524e-08
# Ernest Saves Christmas                           -2.971631e-08 -1.469071e-08
# Ice Age: A Mammoth Christmas                      1.895904e-08  1.771696e-08
# The Queen Family Singalong                        2.059419e-08 -1.646815e-08
# The Beatles: Get Back                             1.344582e-08  4.654362e-09
# ...                                                        ...           ...
# Zodiac                                           -5.359235e-09  2.904548e-08
# Zombie Dumb                                       1.069424e-08 -6.595572e-09
# Zombieland                                       -2.830602e-08  4.135392e-09
# Zoom                                             -6.661338e-16 -9.034058e-09
# Zubaan                                           -9.034058e-09 -9.992007e-16
#
# [10218 rows x 10218 columns]

# %%
non_zero_differences
# Out:
# title                                             Duck the Halls: A Mickey Mouse Christmas Special  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                                      2.220446e-16
# Ernest Saves Christmas                                                                1.652363e-08
# Ice Age: A Mammoth Christmas                                                          6.227653e-09
# The Queen Family Singalong                                                           -1.152215e-08
# The Beatles: Get Back                                                                -7.499368e-09
# ...                                                                                            ...
# Zodiac                                                                               -1.970447e-09
# Zombie Dumb                                                                           2.623732e-08
# Zombieland                                                                           -1.812137e-08
# Zoom                                                                                 -1.280369e-08
# Zubaan                                                                               -2.308524e-08
#
# title                                             Ernest Saves Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special            1.652363e-08
# Ernest Saves Christmas                                     -9.992007e-16
# Ice Age: A Mammoth Christmas                               -1.509850e-08
# The Queen Family Singalong                                  2.091807e-08
# The Beatles: Get Back                                      -2.568563e-08
# ...                                                                  ...
# Zodiac                                                      1.902026e-08
# Zombie Dumb                                                 2.021405e-08
# Zombieland                                                 -2.595800e-09
# Zoom                                                       -2.971631e-08
# Zubaan                                                     -1.469071e-08
#
# title                                             Ice Age: A Mammoth Christmas  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                  6.227653e-09
# Ernest Saves Christmas                                           -1.509850e-08
# Ice Age: A Mammoth Christmas                                               NaN
# The Queen Family Singalong                                       -2.289185e-09
# The Beatles: Get Back                                            -1.663467e-08
# ...                                                                        ...
# Zodiac                                                            2.074595e-10
# Zombie Dumb                                                       5.324672e-09
# Zombieland                                                        2.577316e-08
# Zoom                                                              1.895904e-08
# Zubaan                                                            1.771696e-08
#
# title                                             The Queen Family Singalong  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special               -1.152215e-08
# Ernest Saves Christmas                                          2.091807e-08
# Ice Age: A Mammoth Christmas                                   -2.289185e-09
# The Queen Family Singalong                                               NaN
# The Beatles: Get Back                                          -9.114829e-09
# ...                                                                      ...
# Zodiac                                                         -1.818058e-08
# Zombie Dumb                                                    -2.169410e-08
# Zombieland                                                      1.096099e-08
# Zoom                                                            2.059419e-08
# Zubaan                                                         -1.646815e-08
#
# title                                             The Beatles: Get Back  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special          -7.499368e-09
# Ernest Saves Christmas                                    -2.568563e-08
# Ice Age: A Mammoth Christmas                              -1.663467e-08
# The Queen Family Singalong                                -9.114829e-09
# The Beatles: Get Back                                               NaN
# ...                                                                 ...
# Zodiac                                                     5.775182e-09
# Zombie Dumb                                                1.704469e-08
# Zombieland                                                 2.392026e-08
# Zoom                                                       1.344582e-08
# Zubaan                                                     4.654362e-09
#
# title                                             Becoming Cousteau  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special      -2.198570e-08
# Ernest Saves Christmas                                -2.179413e-08
# Ice Age: A Mammoth Christmas                           2.453709e-08
# The Queen Family Singalong                             2.403032e-08
# The Beatles: Get Back                                 -2.756923e-08
# ...                                                             ...
# Zodiac                                                -9.722748e-09
# Zombie Dumb                                           -2.557839e-08
# Zombieland                                             8.181233e-09
# Zoom                                                  -9.458134e-09
# Zubaan                                                -9.267269e-09
#
# title                                                  Hawkeye  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  2.290304e-08
# Ernest Saves Christmas                           -3.778168e-10
# Ice Age: A Mammoth Christmas                     -2.796784e-08
# The Queen Family Singalong                       -2.358791e-08
# The Beatles: Get Back                             2.778071e-08
# ...                                                        ...
# Zodiac                                            2.252651e-08
# Zombie Dumb                                       1.699923e-08
# Zombieland                                       -8.208098e-09
# Zoom                                              3.679112e-09
# Zubaan                                            1.453180e-08
#
# title                                             Port Protection Alaska  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special           -2.594804e-08
# Ernest Saves Christmas                                      2.949284e-08
# Ice Age: A Mammoth Christmas                               -2.965700e-08
# The Queen Family Singalong                                  5.764674e-09
# The Beatles: Get Back                                       8.805314e-09
# ...                                                                  ...
# Zodiac                                                     -1.675894e-08
# Zombie Dumb                                                -4.026796e-09
# Zombieland                                                  1.292308e-08
# Zoom                                                       -2.328941e-08
# Zubaan                                                     -3.479935e-10
#
# title                                             Secrets of the Zoo: Tampa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special              -2.928809e-09
# Ernest Saves Christmas                                        -1.669076e-08
# Ice Age: A Mammoth Christmas                                   2.499199e-08
# The Queen Family Singalong                                    -9.980401e-09
# The Beatles: Get Back                                         -6.242502e-09
# ...                                                                     ...
# Zodiac                                                        -1.032797e-08
# Zombie Dumb                                                    1.408377e-09
# Zombieland                                                     2.917705e-08
# Zoom                                                           4.379522e-09
# Zubaan                                                        -2.164909e-08
#
# title                                             A Muppets Christmas: Letters To Santa  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special                           5.973625e-09
# Ernest Saves Christmas                                                     2.969237e-08
# Ice Age: A Mammoth Christmas                                              -2.211633e-08
# The Queen Family Singalong                                                -1.159898e-09
# The Beatles: Get Back                                                     -1.543187e-08
# ...                                                                                 ...
# Zodiac                                                                    -2.702201e-08
# Zombie Dumb                                                                1.123894e-08
# Zombieland                                                                -4.808069e-10
# Zoom                                                                      -1.476667e-08
# Zubaan                                                                     1.136509e-08
#
# title                                             ...     Zak Storm  \
# title                                             ...
# Duck the Halls: A Mickey Mouse Christmas Special  ...  1.993738e-08
# Ernest Saves Christmas                            ...  2.386660e-08
# Ice Age: A Mammoth Christmas                      ... -1.938156e-08
# The Queen Family Singalong                        ... -1.505063e-09
# The Beatles: Get Back                             ... -1.010771e-08
# ...                                               ...           ...
# Zodiac                                            ...  1.823680e-08
# Zombie Dumb                                       ... -1.044032e-08
# Zombieland                                        ...  1.217867e-08
# Zoom                                              ... -2.793000e-08
# Zubaan                                            ...  3.664237e-09
#
# title                                                 Zed Plus         Zenda  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special -2.447984e-08 -3.132743e-09
# Ernest Saves Christmas                           -5.466155e-09 -1.720849e-09
# Ice Age: A Mammoth Christmas                     -1.425107e-09  5.247664e-09
# The Queen Family Singalong                        1.440501e-08 -2.060415e-08
# The Beatles: Get Back                            -2.541977e-08  1.969841e-08
# ...                                                        ...           ...
# Zodiac                                           -2.838809e-08  1.833409e-08
# Zombie Dumb                                      -2.262831e-08 -2.186094e-08
# Zombieland                                        1.394895e-08  1.010210e-08
# Zoom                                              2.799868e-08  2.130835e-08
# Zubaan                                            2.573841e-08  1.242346e-08
#
# title                                             Zindagi Gulzar Hai  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special        2.512429e-08
# Ernest Saves Christmas                                 -6.858093e-09
# Ice Age: A Mammoth Christmas                           -1.900347e-08
# The Queen Family Singalong                             -3.645117e-09
# The Beatles: Get Back                                  -5.275413e-09
# ...                                                              ...
# Zodiac                                                  3.689068e-09
# Zombie Dumb                                             2.132165e-08
# Zombieland                                              5.061735e-09
# Zoom                                                    2.548399e-08
# Zubaan                                                  3.713874e-09
#
# title                                                  Zinzana        Zodiac  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special -1.337330e-09 -1.970447e-09
# Ernest Saves Christmas                           -2.245289e-08  1.902026e-08
# Ice Age: A Mammoth Christmas                     -2.055456e-08  2.074595e-10
# The Queen Family Singalong                       -1.598998e-08 -1.818058e-08
# The Beatles: Get Back                            -2.562514e-08  5.775182e-09
# ...                                                        ...           ...
# Zodiac                                            3.776930e-09  1.110223e-15
# Zombie Dumb                                       3.814231e-09  2.268134e-08
# Zombieland                                        1.838143e-08 -6.339777e-09
# Zoom                                             -5.472462e-09 -5.359235e-09
# Zubaan                                            6.067541e-09  2.904548e-08
#
# title                                              Zombie Dumb    Zombieland  \
# title
# Duck the Halls: A Mickey Mouse Christmas Special  2.623732e-08 -1.812137e-08
# Ernest Saves Christmas                            2.021405e-08 -2.595800e-09
# Ice Age: A Mammoth Christmas                      5.324672e-09  2.577316e-08
# The Queen Family Singalong                       -2.169410e-08  1.096099e-08
# The Beatles: Get Back                             1.704469e-08  2.392026e-08
# ...                                                        ...           ...
# Zodiac                                            2.268134e-08 -6.339777e-09
# Zombie Dumb                                       8.881784e-16  2.931105e-08
# Zombieland                                        2.931105e-08 -4.440892e-16
# Zoom                                              1.069424e-08 -2.830602e-08
# Zubaan                                           -6.595572e-09  4.135392e-09
#
# title                                                     Zoom        Zubaan
# title
# Duck the Halls: A Mickey Mouse Christmas Special -1.280369e-08 -2.308524e-08
# Ernest Saves Christmas                           -2.971631e-08 -1.469071e-08
# Ice Age: A Mammoth Christmas                      1.895904e-08  1.771696e-08
# The Queen Family Singalong                        2.059419e-08 -1.646815e-08
# The Beatles: Get Back                             1.344582e-08  4.654362e-09
# ...                                                        ...           ...
# Zodiac                                           -5.359235e-09  2.904548e-08
# Zombie Dumb                                       1.069424e-08 -6.595572e-09
# Zombieland                                       -2.830602e-08  4.135392e-09
# Zoom                                             -6.661338e-16 -9.034058e-09
# Zubaan                                           -9.034058e-09 -9.992007e-16
#
# [10218 rows x 10218 columns]
